# %% [markdown]
# # Matrix Plot
#
# Heat Map
# Pivot Map

# %%
import numpy as np
import seaborn as sns

# %%
flight=sns.load_dataset('flights')
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flightcorre=flight[['passengers','year']]
flightcorre.corr()
# Out:
#             passengers      year
# passengers    1.000000  0.921824
# year          0.921824  1.000000

# %%
sns.heatmap(flightcorre.corr())
# Out:
# <Axes: >
