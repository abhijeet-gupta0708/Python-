# %% [markdown]
# ## NAME : ABHIJEET GUPTA

# %% [markdown]
# ## Find the error in the code

# %% [markdown]
# 1. **Code Snippet 1**

# %%
def add_number(a,b) :
    return a+b
print(add_number(5,6))
# Out:
# 11

# %% [markdown]
# IN the Code Snippt 1 : The Error was missing Coloum Sign and without the coloum sign the python interpreter is not able to access the instruction inside the file

# %% [markdown]
# 2. **Code Snippet 2**

# %%
name ="Alice"
print("Hello , "+name)
# Out:
# Hello , Alice

# %% [markdown]
# In the code Snippet 2 : The error was incomplete double quotation sign meaning that  the name Alice is not consider as a string in the varaible name

# %% [markdown]
# 3. **Code Snippet 3**

# %%
for i in range (5) :
    print ("Number :" , i)
# Out:
# Number : 0
# Number : 1
# Number : 2
# Number : 3
# Number : 4

# %% [markdown]
# The error in code snippet 4 is the absennce of colon

# %% [markdown]
# 4. **Code Snippet 4**

# %%
my_list=[1,2,3,4,5]
print("The fifth element in the list is ",my_list[4])
# Out:
# The fifth element in the list is  5

# %% [markdown]
# In this code snippet , there are two errors
# 1: + symbol insted of ,
# 2: Index error since the list has the indexing strating from 0 ao the five elements have a index of 0-4

# %% [markdown]
# 5. **Code Snippet 5**

# %%
def greet (name) :
    print ("Hello ," +name)
greet ("Bob")
# Out:
# Hello ,Bob

# %% [markdown]
# The error in the code snippet was that the line print ("Hello , "+name) was out the function greet so it will not execute because the name is defined under the greet function

# %% [markdown]
# 6. **Code Snippet 6**

# %%
age =int (input("Enter your age"))
if age>=18 :
    print("You are eligible to vote")
else :
    print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %% [markdown]
# The error in this code snippet was that the age was taking input as a string not as a number which we are later comparing with

# %% [markdown]
# 7. **Code Snippet 7**

# %%
def multiply (a,b):
    result=a*b
    return result
print (multiply(4,5))
# Out:
# 20

# %% [markdown]
# The error in this code snippet was that the return resturn statement was outside the function multiply (a,b) so it will not execute hence not return the answer

# %% [markdown]
# 8. **Code Snippet 8**

# %%
count =10
while(count >0) :
    print (count)
    count -=1

print("Countdown finished")

# %% [markdown]
# The Error in the above code Snippet was missing colon in the while statement
